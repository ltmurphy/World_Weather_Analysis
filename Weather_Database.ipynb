# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the names of cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 714

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]    
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rio grande
# Processing Record 2 of Set 1 | dunedin
# Processing Record 3 of Set 1 | pangody
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pombas
# Processing Record 10 of Set 1 | axim
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | mitchell
# Processing Record 13 of Set 1 | mizoch
# Processing Record 14 of Set 1 | vostok
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | sobolevo
# Processing Record 19 of Set 1 | husavik
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | manitouwadge
# Processing Record 23 of Set 1 | mayumba
# Processing Record 24 of Set 1 | rorvik
# Processing Record 25 of Set 1 | los llanos de aridane
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | sola
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | ola
# Processing Record 31 of Set 1 | ouallam
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | polunochnoye
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | porto velho
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 1 | aboisso
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | leshukonskoye
# Processing Record 43 of Set 1 | oktyabrskiy
# Processing Record 44 of Set 1 | sarangani
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | pangnirtung
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | easley
# Processing Record 2 of Set 2 | yeppoon
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | karratha
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | piracuruca
# Processing Record 9 of Set 2 | ayan
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | san vicente
# Processing Record 12 of Set 2 | junction city
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 2 | kirakira
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | novyy nekouz
# Processing Record 19 of Set 2 | linfen
# Processing Record 20 of Set 2 | sioux lookout
# Processing Record 21 of Set 2 | gaoual
# Processing Record 22 of Set 2 | hungund
# Processing Record 23 of Set 2 | teyateyaneng
# Processing Record 24 of Set 2 | ust-karsk
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | kushmurun
# Processing Record 27 of Set 2 | piranhas
# Processing Record 28 of Set 2 | vallenar
# Processing Record 29 of Set 2 | juneau
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | huarmey
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | davila
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | palmer
# Processing Record 38 of Set 2 | dod ballapur
# Processing Record 39 of Set 2 | lutkun
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | kununurra
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | pandan
# Processing Record 49 of Set 2 | namibe
# Processing Record 50 of Set 2 | ugoofaaru
# Processing Record 1 of Set 3 | ponta delgada
# Processing Record 2 of Set 3 | nantucket
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | batar
# Processing Record 5 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 3 | sangar
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | tanda
# Processing Record 9 of Set 3 | krasnoyarskiy
# Processing Record 10 of Set 3 | conneaut
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | haines junction
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | talaya
# Processing Record 16 of Set 3 | ganta
# Processing Record 17 of Set 3 | pundaguitan
# Processing Record 18 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | taywarah
# Processing Record 21 of Set 3 | nemuro
# Processing Record 22 of Set 3 | preili
# Processing Record 23 of Set 3 | tashla
# Processing Record 24 of Set 3 | saint-joseph
# Processing Record 25 of Set 3 | lazaro cardenas
# Processing Record 26 of Set 3 | shingu
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | bjornevatn
# Processing Record 31 of Set 3 | saint-augustin
# Processing Record 32 of Set 3 | aswan
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | tuskegee
# Processing Record 36 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 37 of Set 3 | tavricheskoye
# Processing Record 38 of Set 3 | vanimo
# Processing Record 39 of Set 3 | penzance
# Processing Record 40 of Set 3 | srandakan
# Processing Record 41 of Set 3 | wuda
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | irmo
# Processing Record 46 of Set 3 | nabire
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | belaya gora
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | chastoozerye
# City not found. Skipping...
# Processing Record 4 of Set 4 | dire dawa
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | gazanjyk
# Processing Record 7 of Set 4 | coihaique
# Processing Record 8 of Set 4 | martapura
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | broome
# Processing Record 11 of Set 4 | tiznit
# Processing Record 12 of Set 4 | manokwari
# Processing Record 13 of Set 4 | barranca
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | saint-francois
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | okhotsk
# Processing Record 19 of Set 4 | wyndham
# Processing Record 20 of Set 4 | nanakuli
# Processing Record 21 of Set 4 | east london
# Processing Record 22 of Set 4 | havre-saint-pierre
# Processing Record 23 of Set 4 | quatre cocos
# Processing Record 24 of Set 4 | hay river
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | bria
# Processing Record 29 of Set 4 | moosomin
# Processing Record 30 of Set 4 | mmabatho
# Processing Record 31 of Set 4 | tunghsiao
# City not found. Skipping...
# Processing Record 32 of Set 4 | olafsvik
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | mudgee
# Processing Record 37 of Set 4 | mae sai
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | puerto colombia
# Processing Record 40 of Set 4 | lima
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | gold coast
# Processing Record 43 of Set 4 | inhambane
# Processing Record 44 of Set 4 | tabas
# Processing Record 45 of Set 4 | hovd
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | mindelo
# Processing Record 48 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 4 | fort walton beach
# Processing Record 50 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | okha
# Processing Record 3 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 5 | ikungi
# Processing Record 5 of Set 5 | borogontsy
# Processing Record 6 of Set 5 | kashi
# Processing Record 7 of Set 5 | jalu
# Processing Record 8 of Set 5 | mount gambier
# Processing Record 9 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | baft
# Processing Record 11 of Set 5 | yaan
# Processing Record 12 of Set 5 | xining
# Processing Record 13 of Set 5 | abha
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | stepnogorsk
# Processing Record 16 of Set 5 | marzuq
# Processing Record 17 of Set 5 | guaira
# Processing Record 18 of Set 5 | necochea
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | takoradi
# Processing Record 21 of Set 5 | caravelas
# Processing Record 22 of Set 5 | camacha
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | kungurtug
# Processing Record 25 of Set 5 | port-gentil
# Processing Record 26 of Set 5 | bharatpur
# Processing Record 27 of Set 5 | gorontalo
# Processing Record 28 of Set 5 | boa vista
# Processing Record 29 of Set 5 | puerto plata
# Processing Record 30 of Set 5 | qeshm
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 5 | skarnes
# Processing Record 34 of Set 5 | ilulissat
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | puerto leguizamo
# Processing Record 37 of Set 5 | kotma
# Processing Record 38 of Set 5 | dolores
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 42 of Set 5 | troitsko-pechorsk
# Processing Record 43 of Set 5 | mnogovershinnyy
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | ust-ishim
# Processing Record 46 of Set 5 | miri
# Processing Record 47 of Set 5 | port hardy
# Processing Record 48 of Set 5 | tungor
# Processing Record 49 of Set 5 | iisalmi
# Processing Record 50 of Set 5 | bonavista
# Processing Record 1 of Set 6 | merauke
# Processing Record 2 of Set 6 | kargasok
# Processing Record 3 of Set 6 | maningrida
# Processing Record 4 of Set 6 | malindi
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | alcantara
# Processing Record 8 of Set 6 | qaanaaq
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | grootfontein
# Processing Record 12 of Set 6 | port hedland
# Processing Record 13 of Set 6 | tukrah
# Processing Record 14 of Set 6 | meulaboh
# Processing Record 15 of Set 6 | verkh-usugli
# Processing Record 16 of Set 6 | thompson
# Processing Record 17 of Set 6 | green river
# Processing Record 18 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | amuntai
# Processing Record 22 of Set 6 | nago
# Processing Record 23 of Set 6 | kutum
# Processing Record 24 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | toyo
# Processing Record 27 of Set 6 | tabuk
# Processing Record 28 of Set 6 | la ronge
# Processing Record 29 of Set 6 | katete
# Processing Record 30 of Set 6 | quang ngai
# Processing Record 31 of Set 6 | ponta do sol
# Processing Record 32 of Set 6 | garissa
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | waipawa
# Processing Record 35 of Set 6 | carmo do rio claro
# Processing Record 36 of Set 6 | brigantine
# Processing Record 37 of Set 6 | bukachacha
# Processing Record 38 of Set 6 | kyshtovka
# Processing Record 39 of Set 6 | kulhudhuffushi
# Processing Record 40 of Set 6 | rocha
# Processing Record 41 of Set 6 | lichtenburg
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | bayevo
# Processing Record 44 of Set 6 | londonderry
# Processing Record 45 of Set 6 | leh
# Processing Record 46 of Set 6 | chekalin
# Processing Record 47 of Set 6 | nivala
# Processing Record 48 of Set 6 | kahului
# Processing Record 49 of Set 6 | pisco
# Processing Record 50 of Set 6 | nawabshah
# Processing Record 1 of Set 7 | irinjalakuda
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | buenaventura
# Processing Record 4 of Set 7 | marienburg
# Processing Record 5 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 7 | tofield
# Processing Record 7 of Set 7 | yerbogachen
# Processing Record 8 of Set 7 | prince rupert
# Processing Record 9 of Set 7 | bambous virieux
# Processing Record 10 of Set 7 | uhlove
# Processing Record 11 of Set 7 | iquique
# Processing Record 12 of Set 7 | zhigansk
# Processing Record 13 of Set 7 | alofi
# Processing Record 14 of Set 7 | jinchang
# Processing Record 15 of Set 7 | tateyama
# Processing Record 16 of Set 7 | mecca
# Processing Record 17 of Set 7 | ossora
# Processing Record 18 of Set 7 | bucerias
# Processing Record 19 of Set 7 | uruzgan
# Processing Record 20 of Set 7 | fernie
# Processing Record 21 of Set 7 | the valley
# Processing Record 22 of Set 7 | qianan
# Processing Record 23 of Set 7 | westport
# Processing Record 24 of Set 7 | calatayud
# Processing Record 25 of Set 7 | wanning
# Processing Record 26 of Set 7 | aurillac
# Processing Record 27 of Set 7 | longyearbyen
# Processing Record 28 of Set 7 | clyde river
# Processing Record 29 of Set 7 | whitehorse
# Processing Record 30 of Set 7 | meadow lake
# Processing Record 31 of Set 7 | tessalit
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | san policarpo
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | ayoquezco
# City not found. Skipping...
# Processing Record 36 of Set 7 | guangyuan
# Processing Record 37 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | bhanpura
# Processing Record 40 of Set 7 | saldanha
# Processing Record 41 of Set 7 | puerto penasco
# Processing Record 42 of Set 7 | mahibadhoo
# Processing Record 43 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 7 | iwanai
# Processing Record 45 of Set 7 | chapais
# Processing Record 46 of Set 7 | klyuchi
# Processing Record 47 of Set 7 | peski
# Processing Record 48 of Set 7 | suntar
# Processing Record 49 of Set 7 | lompoc
# Processing Record 50 of Set 7 | riyadh
# Processing Record 1 of Set 8 | vao
# Processing Record 2 of Set 8 | kysyl-syr
# Processing Record 3 of Set 8 | winnemucca
# Processing Record 4 of Set 8 | araouane
# Processing Record 5 of Set 8 | moron
# Processing Record 6 of Set 8 | jilin
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | ilheus
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | nikolskoye
# Processing Record 11 of Set 8 | solnechnyy
# Processing Record 12 of Set 8 | alyangula
# Processing Record 13 of Set 8 | bandarbeyla
# Processing Record 14 of Set 8 | narsaq
# Processing Record 15 of Set 8 | tambopata
# Processing Record 16 of Set 8 | tomohon
# Processing Record 17 of Set 8 | matagami
# Processing Record 18 of Set 8 | anadyr
# Processing Record 19 of Set 8 | betulia
# Processing Record 20 of Set 8 | ribeira grande
# Processing Record 21 of Set 8 | vieux-habitants
# Processing Record 22 of Set 8 | soyo
# Processing Record 23 of Set 8 | yulara
# Processing Record 24 of Set 8 | taoudenni
# Processing Record 25 of Set 8 | willowmore
# Processing Record 26 of Set 8 | lund
# Processing Record 27 of Set 8 | san cristobal
# Processing Record 28 of Set 8 | nueva granada
# Processing Record 29 of Set 8 | mattawa
# Processing Record 30 of Set 8 | sisimiut
# Processing Record 31 of Set 8 | bambanglipuro
# Processing Record 32 of Set 8 | qandala
# Processing Record 33 of Set 8 | bull savanna
# Processing Record 34 of Set 8 | broken hill
# Processing Record 35 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 8 | nelson bay
# Processing Record 37 of Set 8 | ust-kuyga
# Processing Record 38 of Set 8 | santa cruz del sur
# Processing Record 39 of Set 8 | denia
# Processing Record 40 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 41 of Set 8 | valley city
# Processing Record 42 of Set 8 | talara
# Processing Record 43 of Set 8 | havre
# Processing Record 44 of Set 8 | ngunguru
# Processing Record 45 of Set 8 | luxor
# Processing Record 46 of Set 8 | chuy
# Processing Record 47 of Set 8 | xuddur
# Processing Record 48 of Set 8 | kokkola
# Processing Record 49 of Set 8 | pedro carbo
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | tombouctou
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | port elizabeth
# Processing Record 4 of Set 9 | adre
# Processing Record 5 of Set 9 | sarkand
# Processing Record 6 of Set 9 | belyy yar
# Processing Record 7 of Set 9 | dawson creek
# Processing Record 8 of Set 9 | copiague
# Processing Record 9 of Set 9 | magistralnyy
# Processing Record 10 of Set 9 | lishu
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | lasa
# Processing Record 13 of Set 9 | sibolga
# Processing Record 14 of Set 9 | burica
# City not found. Skipping...
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | aracataca
# Processing Record 17 of Set 9 | luba
# Processing Record 18 of Set 9 | seoul
# Processing Record 19 of Set 9 | channel-port aux basques
# Processing Record 20 of Set 9 | baykit
# Processing Record 21 of Set 9 | itarema
# Processing Record 22 of Set 9 | dakar
# Processing Record 23 of Set 9 | tuy hoa
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | char bhadrasan
# Processing Record 27 of Set 9 | kalaleh
# Processing Record 28 of Set 9 | les cayes
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | simbahan
# Processing Record 31 of Set 9 | gravdal
# Processing Record 32 of Set 9 | klishkivtsi
# Processing Record 33 of Set 9 | sur
# Processing Record 34 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 9 | andenes
# Processing Record 36 of Set 9 | pirapozinho
# Processing Record 37 of Set 9 | comodoro rivadavia
# Processing Record 38 of Set 9 | russell
# Processing Record 39 of Set 9 | naze
# Processing Record 40 of Set 9 | gonda
# Processing Record 41 of Set 9 | filadelfia
# Processing Record 42 of Set 9 | ornes
# Processing Record 43 of Set 9 | salekhard
# Processing Record 44 of Set 9 | la romana
# Processing Record 45 of Set 9 | acapulco
# Processing Record 46 of Set 9 | lamu
# Processing Record 47 of Set 9 | birao
# Processing Record 48 of Set 9 | sinnamary
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | san pedro
# Processing Record 1 of Set 10 | isangel
# Processing Record 2 of Set 10 | kefamenanu
# Processing Record 3 of Set 10 | salinas
# Processing Record 4 of Set 10 | cairns
# Processing Record 5 of Set 10 | oakdale
# Processing Record 6 of Set 10 | laurel
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | houma
# Processing Record 9 of Set 10 | egvekinot
# Processing Record 10 of Set 10 | vardo
# Processing Record 11 of Set 10 | asfi
# Processing Record 12 of Set 10 | dhidhdhoo
# Processing Record 13 of Set 10 | iqaluit
# Processing Record 14 of Set 10 | maicao
# Processing Record 15 of Set 10 | werda
# Processing Record 16 of Set 10 | annau
# Processing Record 17 of Set 10 | we
# City not found. Skipping...
# Processing Record 18 of Set 10 | manaus
# Processing Record 19 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 10 | bar harbor
# Processing Record 21 of Set 10 | meaford
# Processing Record 22 of Set 10 | timizart
# Processing Record 23 of Set 10 | vatne
# Processing Record 24 of Set 10 | santa isabel do rio negro
# Processing Record 25 of Set 10 | barao de cocais
# Processing Record 26 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 27 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 10 | llangefni
# Processing Record 29 of Set 10 | aykhal
# Processing Record 30 of Set 10 | shimoda
# Processing Record 31 of Set 10 | kodinsk
# Processing Record 32 of Set 10 | saint-georges
# Processing Record 33 of Set 10 | josanicka banja
# Processing Record 34 of Set 10 | bubaque
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | ambilobe
# Processing Record 37 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 10 | surt
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | oistins
# Processing Record 43 of Set 10 | trapani
# Processing Record 44 of Set 10 | vyazemskiy
# Processing Record 45 of Set 10 | panzhihua
# Processing Record 46 of Set 10 | luderitz
# Processing Record 47 of Set 10 | storforshei
# Processing Record 48 of Set 10 | santa cruz
# Processing Record 49 of Set 10 | kiama
# Processing Record 50 of Set 10 | adrar
# Processing Record 1 of Set 11 | ambon
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | maamba
# Processing Record 4 of Set 11 | ipixuna
# Processing Record 5 of Set 11 | raton
# Processing Record 6 of Set 11 | ken caryl
# Processing Record 7 of Set 11 | luanda
# Processing Record 8 of Set 11 | bandar-e lengeh
# Processing Record 9 of Set 11 | paraiso
# Processing Record 10 of Set 11 | marsh harbour
# Processing Record 11 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 12 of Set 11 | bolkhov
# Processing Record 13 of Set 11 | carballo
# Processing Record 14 of Set 11 | coahuayana
# Processing Record 15 of Set 11 | pangai
# Processing Record 16 of Set 11 | arequipa
# Processing Record 17 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 11 | tahe
# Processing Record 19 of Set 11 | aripuana
# Processing Record 20 of Set 11 | sabha
# Processing Record 21 of Set 11 | bathsheba
# Processing Record 22 of Set 11 | asau
# Processing Record 23 of Set 11 | kloulklubed
# Processing Record 24 of Set 11 | semnan
# Processing Record 25 of Set 11 | cockburn town
# Processing Record 26 of Set 11 | oranjemund
# Processing Record 27 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 28 of Set 11 | kudahuvadhoo
# Processing Record 29 of Set 11 | ambulu
# Processing Record 30 of Set 11 | khovu-aksy
# Processing Record 31 of Set 11 | maunabo
# Processing Record 32 of Set 11 | tanah merah
# Processing Record 33 of Set 11 | poum
# Processing Record 34 of Set 11 | ripky
# Processing Record 35 of Set 11 | saint anthony
# Processing Record 36 of Set 11 | san patricio
# Processing Record 37 of Set 11 | lerik
# Processing Record 38 of Set 11 | padang
# Processing Record 39 of Set 11 | baton rouge
# Processing Record 40 of Set 11 | semporna
# Processing Record 41 of Set 11 | ucluelet
# Processing Record 42 of Set 11 | leningradskiy
# Processing Record 43 of Set 11 | bima
# Processing Record 44 of Set 11 | maldonado
# Processing Record 45 of Set 11 | trairi
# Processing Record 46 of Set 11 | morehead
# Processing Record 47 of Set 11 | olga
# Processing Record 48 of Set 11 | sharjah
# Processing Record 49 of Set 11 | ust-nera
# Processing Record 50 of Set 11 | hun
# Processing Record 1 of Set 12 | talnakh
# Processing Record 2 of Set 12 | kruisfontein
# Processing Record 3 of Set 12 | henties bay
# Processing Record 4 of Set 12 | deputatskiy
# Processing Record 5 of Set 12 | karpogory
# Processing Record 6 of Set 12 | wajima
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | tres picos
# Processing Record 9 of Set 12 | sesheke
# Processing Record 10 of Set 12 | dong xoai
# Processing Record 11 of Set 12 | acarau
# Processing Record 12 of Set 12 | warwick
# Processing Record 13 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 12 | katherine
# Processing Record 15 of Set 12 | te anau
# Processing Record 16 of Set 12 | blackwater
# Processing Record 17 of Set 12 | nouadhibou
# Processing Record 18 of Set 12 | orlik
# Processing Record 19 of Set 12 | cordoba
# Processing Record 20 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 12 | cheremukhovo
# Processing Record 22 of Set 12 | mount isa
# Processing Record 23 of Set 12 | ust-omchug
# Processing Record 24 of Set 12 | morros
# Processing Record 25 of Set 12 | pringsewu
# Processing Record 26 of Set 12 | nylstroom
# City not found. Skipping...
# Processing Record 27 of Set 12 | mastacani
# Processing Record 28 of Set 12 | ilhabela
# Processing Record 29 of Set 12 | rustenburg
# Processing Record 30 of Set 12 | huilong
# Processing Record 31 of Set 12 | gobabis
# Processing Record 32 of Set 12 | alta floresta
# Processing Record 33 of Set 12 | barhi
# Processing Record 34 of Set 12 | nushki
# Processing Record 35 of Set 12 | nikolayevsk-na-amure
# Processing Record 36 of Set 12 | isiro
# Processing Record 37 of Set 12 | morshansk
# Processing Record 38 of Set 12 | wittmund
# Processing Record 39 of Set 12 | porto novo
# Processing Record 40 of Set 12 | morant bay
# Processing Record 41 of Set 12 | sao joao da barra
# Processing Record 42 of Set 12 | edson
# Processing Record 43 of Set 12 | bom jesus
# Processing Record 44 of Set 12 | mitsamiouli
# Processing Record 45 of Set 12 | nosy varika
# Processing Record 46 of Set 12 | xinzhou
# Processing Record 47 of Set 12 | boende
# Processing Record 48 of Set 12 | thoen
# Processing Record 49 of Set 12 | mercedes
# Processing Record 50 of Set 12 | vestmannaeyjar
# Processing Record 1 of Set 13 | port macquarie
# Processing Record 2 of Set 13 | skala
# Processing Record 3 of Set 13 | laje
# Processing Record 4 of Set 13 | saint-pierre
# Processing Record 5 of Set 13 | harnosand
# Processing Record 6 of Set 13 | san rafael del sur
# Processing Record 7 of Set 13 | samana
# Processing Record 8 of Set 13 | pitimbu
# Processing Record 9 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 10 of Set 13 | kirkenaer
# Processing Record 11 of Set 13 | khuzdar
# Processing Record 12 of Set 13 | scarborough
# Processing Record 13 of Set 13 | charters towers
# Processing Record 14 of Set 13 | aranos
# Processing Record 15 of Set 13 | boysun
# Processing Record 16 of Set 13 | pacific grove
# Processing Record 17 of Set 13 | adeje
# Processing Record 18 of Set 13 | bako
# Processing Record 19 of Set 13 | puquio
# Processing Record 20 of Set 13 | novobirilyussy
# Processing Record 21 of Set 13 | barra do garcas
# Processing Record 22 of Set 13 | beruwala
# Processing Record 23 of Set 13 | enid
# Processing Record 24 of Set 13 | san benito
# Processing Record 25 of Set 13 | berlevag
# Processing Record 26 of Set 13 | omsukchan
# Processing Record 27 of Set 13 | sulphur springs
# Processing Record 28 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 13 | noumea
# Processing Record 30 of Set 13 | topi
# Processing Record 31 of Set 13 | vangaindrano
# Processing Record 32 of Set 13 | phu khieo
# City not found. Skipping...
# Processing Record 33 of Set 13 | toba tek singh
# Processing Record 34 of Set 13 | puerto escondido
# Processing Record 35 of Set 13 | avera
# Processing Record 36 of Set 13 | seminole
# Processing Record 37 of Set 13 | grand gaube
# Processing Record 38 of Set 13 | dovolnoye
# Processing Record 39 of Set 13 | mitu
# Processing Record 40 of Set 13 | villahermosa
# Processing Record 41 of Set 13 | kangaatsiaq
# Processing Record 42 of Set 13 | bryant
# Processing Record 43 of Set 13 | gainesville
# Processing Record 44 of Set 13 | lavrentiya
# Processing Record 45 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 46 of Set 13 | pemberton
# Processing Record 47 of Set 13 | cotonou
# Processing Record 48 of Set 13 | rockhampton
# Processing Record 49 of Set 13 | tocopilla
# Processing Record 50 of Set 13 | esmeraldas
# Processing Record 1 of Set 14 | arlit
# Processing Record 2 of Set 14 | igarka
# Processing Record 3 of Set 14 | santa rosa
# Processing Record 4 of Set 14 | kapenguria
# Processing Record 5 of Set 14 | safaga
# Processing Record 6 of Set 14 | kaka
# Processing Record 7 of Set 14 | hobyo
# Processing Record 8 of Set 14 | severobaykalsk
# Processing Record 9 of Set 14 | labuhan
# Processing Record 10 of Set 14 | erzin
# Processing Record 11 of Set 14 | saint-ambroise
# Processing Record 12 of Set 14 | tirumullaivasal
# Processing Record 13 of Set 14 | lusambo
# Processing Record 14 of Set 14 | sovetskiy
# Processing Record 15 of Set 14 | anamur
# Processing Record 16 of Set 14 | inayagan
# Processing Record 17 of Set 14 | launceston
# Processing Record 18 of Set 14 | kralendijk
# Processing Record 19 of Set 14 | muscat
# Processing Record 20 of Set 14 | calvia
# Processing Record 21 of Set 14 | alexandroupoli
# Processing Record 22 of Set 14 | truro
# Processing Record 23 of Set 14 | san jeronimo
# Processing Record 24 of Set 14 | payo
# Processing Record 25 of Set 14 | marsa matruh
# Processing Record 26 of Set 14 | erenhot
# Processing Record 27 of Set 14 | sydney
# Processing Record 28 of Set 14 | cap malheureux
# Processing Record 29 of Set 14 | novoagansk
# Processing Record 30 of Set 14 | inirida
# Processing Record 31 of Set 14 | vikulovo
# Processing Record 32 of Set 14 | nanganga
# Processing Record 33 of Set 14 | bilma
# Processing Record 34 of Set 14 | sept-iles
# Processing Record 35 of Set 14 | birin
# Processing Record 36 of Set 14 | tawau
# Processing Record 37 of Set 14 | krasnoselkup
# Processing Record 38 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 14 | korla
# Processing Record 40 of Set 14 | micheweni
# Processing Record 41 of Set 14 | inuvik
# Processing Record 42 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 14 | muroto
# Processing Record 44 of Set 14 | college
# Processing Record 45 of Set 14 | kavaratti
# Processing Record 46 of Set 14 | gladstone
# Processing Record 47 of Set 14 | romny
# Processing Record 48 of Set 14 | mbekenyera
# Processing Record 49 of Set 14 | riberalta
# Processing Record 50 of Set 14 | muisne
# Processing Record 1 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 15 | moose factory
# Processing Record 3 of Set 15 | manacapuru
# Processing Record 4 of Set 15 | luan
# Processing Record 5 of Set 15 | stokmarknes
# Processing Record 6 of Set 15 | notre-dame-du-lac
# Processing Record 7 of Set 15 | port antonio
# Processing Record 8 of Set 15 | moskovskiy
# Processing Record 9 of Set 15 | killam
# Processing Record 10 of Set 15 | tilichiki
# Processing Record 11 of Set 15 | popondetta
# Processing Record 12 of Set 15 | mao
# Processing Record 13 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 15 | dongning
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 661

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Rio Grande      BR -32.0350  -52.0986     55.94        70           0
# 1      Dunedin      NZ -45.8742  170.5036     52.81        85          96
# 2      Pangody      RU  65.8500   74.4859     38.77        96         100
# 3    Cape Town      ZA -33.9258   18.4232     53.28        69           0
# 4      Ushuaia      AR -54.8000  -68.3000     51.46        58          75
# 5       Albany      US  42.6001  -73.9662     51.75        77          80
# 6  Tuktoyaktuk      CA  69.4541 -133.0374     24.80        93          75
# 7      Rikitea      PF -23.1203 -134.9692     75.58        76          16
# 8       Pombas      CV  17.1503  -25.0201     74.98        78           2
# 9         Axim      GH   4.8699   -2.2405     77.05        89          74
#
#    Wind Speed Current Description
# 0        8.08           clear sky
# 1       13.00     overcast clouds
# 2       17.40          light rain
# 3        4.61           clear sky
# 4        6.91       broken clouds
# 5        5.99       broken clouds
# 6        5.75       broken clouds
# 7       13.98          light rain
# 8        8.30           clear sky
# 9        6.22       moderate rain

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City ID")
