# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the names of cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]    
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | tay ninh
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | marawi
# Processing Record 11 of Set 1 | dolores
# Processing Record 12 of Set 1 | matagami
# Processing Record 13 of Set 1 | bay city
# Processing Record 14 of Set 1 | hamilton
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | vondrozo
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | shuiji
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | yanam
# Processing Record 29 of Set 1 | alofi
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | bullhead city
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | elk
# Processing Record 36 of Set 1 | hamada
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | waipawa
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | maltahohe
# Processing Record 43 of Set 1 | nantucket
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | santo antonio do leverger
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | kropotkin
# Processing Record 2 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 2 | rovaniemi
# Processing Record 4 of Set 2 | prince george
# Processing Record 5 of Set 2 | tiarei
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 2 | padang
# Processing Record 10 of Set 2 | ghimbav
# Processing Record 11 of Set 2 | xiaoweizhai
# Processing Record 12 of Set 2 | kiunga
# Processing Record 13 of Set 2 | bowen
# Processing Record 14 of Set 2 | novonikolsk
# Processing Record 15 of Set 2 | gurlan
# Processing Record 16 of Set 2 | raudeberg
# Processing Record 17 of Set 2 | othaya
# Processing Record 18 of Set 2 | kudahuvadhoo
# Processing Record 19 of Set 2 | vuktyl
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | port keats
# Processing Record 22 of Set 2 | los llanos de aridane
# Processing Record 23 of Set 2 | sept-iles
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | pasighat
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 2 | hun
# Processing Record 32 of Set 2 | tecoanapa
# Processing Record 33 of Set 2 | adrar
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | jablanica
# Processing Record 39 of Set 2 | olenino
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | alice springs
# Processing Record 42 of Set 2 | kilis
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | mbandaka
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | tank
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | lorengau
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | tilichiki
# Processing Record 6 of Set 3 | guaymas
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | puerto escondido
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | bondo
# Processing Record 13 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 3 | bonavista
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | iglesias
# Processing Record 17 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 3 | brodokalmak
# Processing Record 19 of Set 3 | ballinasloe
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | wattegama
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | beira
# Processing Record 26 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | elizabeth city
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | baherden
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | zyryanka
# Processing Record 33 of Set 3 | ulychne
# Processing Record 34 of Set 3 | shoreview
# Processing Record 35 of Set 3 | mandan
# Processing Record 36 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | clinton
# Processing Record 43 of Set 3 | cabra
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | ixtapa
# Processing Record 46 of Set 3 | mogadishu
# Processing Record 47 of Set 3 | srandakan
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | abu dhabi
# Processing Record 1 of Set 4 | oranjemund
# Processing Record 2 of Set 4 | lieksa
# Processing Record 3 of Set 4 | raciborz
# Processing Record 4 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | gigmoto
# Processing Record 7 of Set 4 | diffa
# Processing Record 8 of Set 4 | cockburn town
# Processing Record 9 of Set 4 | pringsewu
# Processing Record 10 of Set 4 | nabire
# Processing Record 11 of Set 4 | narsaq
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | mihara
# Processing Record 15 of Set 4 | glendive
# Processing Record 16 of Set 4 | paltinis
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | belmonte
# Processing Record 19 of Set 4 | buraydah
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | krusa
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | goya
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | waingapu
# Processing Record 26 of Set 4 | dwarka
# Processing Record 27 of Set 4 | narasannapeta
# Processing Record 28 of Set 4 | vanavara
# Processing Record 29 of Set 4 | yar-sale
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | tahoua
# Processing Record 32 of Set 4 | hilo
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | hanna
# Processing Record 35 of Set 4 | tabas
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | kommunisticheskiy
# Processing Record 38 of Set 4 | boyolangu
# Processing Record 39 of Set 4 | nur
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | palomares
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | ereymentau
# Processing Record 46 of Set 4 | maningrida
# Processing Record 47 of Set 4 | flinders
# Processing Record 48 of Set 4 | muisne
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | aykhal
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | yingkou
# Processing Record 6 of Set 5 | zychlin
# Processing Record 7 of Set 5 | hailar
# Processing Record 8 of Set 5 | novyy urgal
# Processing Record 9 of Set 5 | poso
# Processing Record 10 of Set 5 | lala
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | morondava
# Processing Record 13 of Set 5 | mantua
# Processing Record 14 of Set 5 | elverum
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | balkhash
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | bilma
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | northam
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | nandgaon
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | hlotse
# Processing Record 26 of Set 5 | zhangye
# Processing Record 27 of Set 5 | san andres
# Processing Record 28 of Set 5 | karaton
# Processing Record 29 of Set 5 | chicama
# Processing Record 30 of Set 5 | nome
# Processing Record 31 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 5 | hanmer springs
# Processing Record 33 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 5 | rawah
# Processing Record 35 of Set 5 | meadow lake
# Processing Record 36 of Set 5 | walla walla
# Processing Record 37 of Set 5 | vardo
# Processing Record 38 of Set 5 | trapani
# Processing Record 39 of Set 5 | kyaikkami
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | svetlogorsk
# Processing Record 43 of Set 5 | zmeinogorsk
# Processing Record 44 of Set 5 | ilebo
# Processing Record 45 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 5 | mana
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | cabedelo
# Processing Record 49 of Set 5 | mbaiki
# Processing Record 50 of Set 5 | san pedro
# Processing Record 1 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 6 | biak
# Processing Record 3 of Set 6 | chenghai
# Processing Record 4 of Set 6 | narrabri
# Processing Record 5 of Set 6 | candido mendes
# Processing Record 6 of Set 6 | mersing
# Processing Record 7 of Set 6 | ust-uda
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | nieuw amsterdam
# Processing Record 11 of Set 6 | san policarpo
# Processing Record 12 of Set 6 | planadas
# Processing Record 13 of Set 6 | puri
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | birao
# Processing Record 16 of Set 6 | skibbereen
# Processing Record 17 of Set 6 | seoul
# Processing Record 18 of Set 6 | inyonga
# Processing Record 19 of Set 6 | siparia
# Processing Record 20 of Set 6 | trikala
# Processing Record 21 of Set 6 | toowoomba
# Processing Record 22 of Set 6 | mandera
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | hualmay
# Processing Record 25 of Set 6 | trelew
# Processing Record 26 of Set 6 | lodhikheda
# Processing Record 27 of Set 6 | hambantota
# Processing Record 28 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | maibong
# Processing Record 31 of Set 6 | trincomalee
# Processing Record 32 of Set 6 | u thong
# Processing Record 33 of Set 6 | grand forks
# Processing Record 34 of Set 6 | redlands
# Processing Record 35 of Set 6 | san quintin
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | abu kamal
# Processing Record 38 of Set 6 | anaco
# Processing Record 39 of Set 6 | bumbuna
# Processing Record 40 of Set 6 | vila franca do campo
# Processing Record 41 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 42 of Set 6 | bullas
# Processing Record 43 of Set 6 | capitao poco
# Processing Record 44 of Set 6 | salem
# Processing Record 45 of Set 6 | jibuti
# Processing Record 46 of Set 6 | kaitangata
# Processing Record 47 of Set 6 | tres arroyos
# Processing Record 48 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 6 | gazli
# Processing Record 50 of Set 6 | lengshuitan
# Processing Record 1 of Set 7 | bissora
# Processing Record 2 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 7 | olavarria
# Processing Record 4 of Set 7 | newport
# Processing Record 5 of Set 7 | chipinge
# Processing Record 6 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 7 | dyakonovo
# City not found. Skipping...
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 7 | fairview
# Processing Record 11 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 7 | khargone
# Processing Record 13 of Set 7 | port hardy
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | bubaque
# Processing Record 16 of Set 7 | byron bay
# Processing Record 17 of Set 7 | tateyama
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 7 | bitburg
# Processing Record 21 of Set 7 | bolzano
# Processing Record 22 of Set 7 | baruun-urt
# Processing Record 23 of Set 7 | grand gaube
# Processing Record 24 of Set 7 | hauterive
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | haapiti
# Processing Record 28 of Set 7 | udachnyy
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | karratha
# Processing Record 31 of Set 7 | randudongkal
# Processing Record 32 of Set 7 | sosnovo-ozerskoye
# Processing Record 33 of Set 7 | terre haute
# Processing Record 34 of Set 7 | ballina
# Processing Record 35 of Set 7 | riaba
# City not found. Skipping...
# Processing Record 36 of Set 7 | plettenberg bay
# Processing Record 37 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 7 | grindavik
# Processing Record 39 of Set 7 | le passage
# Processing Record 40 of Set 7 | tezu
# Processing Record 41 of Set 7 | rawson
# Processing Record 42 of Set 7 | verkhnyaya sinyachikha
# Processing Record 43 of Set 7 | ulkan
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | gat
# Processing Record 46 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | marathon
# Processing Record 49 of Set 7 | salalah
# Processing Record 50 of Set 7 | yamada
# Processing Record 1 of Set 8 | marihatag
# Processing Record 2 of Set 8 | alyangula
# Processing Record 3 of Set 8 | evanston
# Processing Record 4 of Set 8 | vestmanna
# Processing Record 5 of Set 8 | nizhneangarsk
# Processing Record 6 of Set 8 | dukat
# Processing Record 7 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 8 | nortelandia
# Processing Record 9 of Set 8 | candelaria
# Processing Record 10 of Set 8 | batagay
# Processing Record 11 of Set 8 | faya
# Processing Record 12 of Set 8 | mount isa
# Processing Record 13 of Set 8 | nagai
# Processing Record 14 of Set 8 | palauig
# Processing Record 15 of Set 8 | balkanabat
# Processing Record 16 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | togur
# Processing Record 19 of Set 8 | saint-augustin
# Processing Record 20 of Set 8 | valle hermoso
# Processing Record 21 of Set 8 | hasaki
# Processing Record 22 of Set 8 | kama
# Processing Record 23 of Set 8 | belebey
# Processing Record 24 of Set 8 | cedar city
# Processing Record 25 of Set 8 | manzhouli
# Processing Record 26 of Set 8 | linqiong
# Processing Record 27 of Set 8 | manicore
# Processing Record 28 of Set 8 | mastic beach
# Processing Record 29 of Set 8 | loudi
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | leningradskiy
# Processing Record 32 of Set 8 | kochi
# Processing Record 33 of Set 8 | bira
# Processing Record 34 of Set 8 | borogontsy
# Processing Record 35 of Set 8 | saint george
# Processing Record 36 of Set 8 | naze
# Processing Record 37 of Set 8 | batagay-alyta
# Processing Record 38 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 8 | sao joao da barra
# Processing Record 40 of Set 8 | chemal
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | mendi
# Processing Record 43 of Set 8 | christchurch
# Processing Record 44 of Set 8 | vao
# Processing Record 45 of Set 8 | georgiyevka
# Processing Record 46 of Set 8 | yumen
# Processing Record 47 of Set 8 | meulaboh
# Processing Record 48 of Set 8 | hailin
# Processing Record 49 of Set 8 | tessalit
# Processing Record 50 of Set 8 | uruzgan
# Processing Record 1 of Set 9 | salou
# Processing Record 2 of Set 9 | qui nhon
# Processing Record 3 of Set 9 | duiwelskloof
# Processing Record 4 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 9 | matara
# Processing Record 6 of Set 9 | kattivakkam
# Processing Record 7 of Set 9 | ginir
# Processing Record 8 of Set 9 | lezajsk
# Processing Record 9 of Set 9 | ngunguru
# Processing Record 10 of Set 9 | goragorskiy
# Processing Record 11 of Set 9 | vila velha
# Processing Record 12 of Set 9 | yeniseysk
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | akyab
# Processing Record 15 of Set 9 | tautira
# Processing Record 16 of Set 9 | tonstad
# Processing Record 17 of Set 9 | beloha
# Processing Record 18 of Set 9 | daru
# Processing Record 19 of Set 9 | yulara
# Processing Record 20 of Set 9 | kleive
# Processing Record 21 of Set 9 | pemangkat
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | port macquarie
# Processing Record 24 of Set 9 | alamosa
# Processing Record 25 of Set 9 | sindou
# Processing Record 26 of Set 9 | ipixuna
# Processing Record 27 of Set 9 | ambilobe
# Processing Record 28 of Set 9 | miraflores
# Processing Record 29 of Set 9 | koupela
# Processing Record 30 of Set 9 | siavonga
# Processing Record 31 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 9 | lata
# Processing Record 33 of Set 9 | bulgan
# Processing Record 34 of Set 9 | puerto colombia
# Processing Record 35 of Set 9 | huescar
# Processing Record 36 of Set 9 | anloga
# Processing Record 37 of Set 9 | eyl
# Processing Record 38 of Set 9 | rodrigues alves
# Processing Record 39 of Set 9 | inta
# Processing Record 40 of Set 9 | yefremov
# Processing Record 41 of Set 9 | jaca
# Processing Record 42 of Set 9 | olafsvik
# Processing Record 43 of Set 9 | lovozero
# Processing Record 44 of Set 9 | emerald
# Processing Record 45 of Set 9 | tura
# Processing Record 46 of Set 9 | honggang
# Processing Record 47 of Set 9 | lower burrell
# Processing Record 48 of Set 9 | maumere
# Processing Record 49 of Set 9 | ibicarai
# Processing Record 50 of Set 9 | fraga
# Processing Record 1 of Set 10 | kidal
# Processing Record 2 of Set 10 | bambanglipuro
# Processing Record 3 of Set 10 | yerbogachen
# Processing Record 4 of Set 10 | okha
# Processing Record 5 of Set 10 | dawei
# Processing Record 6 of Set 10 | mount pleasant
# Processing Record 7 of Set 10 | dingle
# Processing Record 8 of Set 10 | zaria
# Processing Record 9 of Set 10 | maniwaki
# Processing Record 10 of Set 10 | inongo
# Processing Record 11 of Set 10 | tromso
# Processing Record 12 of Set 10 | copiapo
# Processing Record 13 of Set 10 | yamethin
# Processing Record 14 of Set 10 | basco
# Processing Record 15 of Set 10 | kindersley
# Processing Record 16 of Set 10 | carmo do rio claro
# Processing Record 17 of Set 10 | tambura
# Processing Record 18 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | balikpapan
# Processing Record 20 of Set 10 | high rock
# Processing Record 21 of Set 10 | nemuro
# Processing Record 22 of Set 10 | lewiston
# Processing Record 23 of Set 10 | saint simons
# Processing Record 24 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 10 | milton
# Processing Record 26 of Set 10 | saebovik
# City not found. Skipping...
# Processing Record 27 of Set 10 | nhulunbuy
# Processing Record 28 of Set 10 | maloy
# Processing Record 29 of Set 10 | sorong
# Processing Record 30 of Set 10 | kishanpur
# Processing Record 31 of Set 10 | sliven
# Processing Record 32 of Set 10 | mayo
# Processing Record 33 of Set 10 | ulladulla
# Processing Record 34 of Set 10 | xichang
# Processing Record 35 of Set 10 | bure
# Processing Record 36 of Set 10 | cabatuan
# Processing Record 37 of Set 10 | dakar
# Processing Record 38 of Set 10 | svetlaya
# Processing Record 39 of Set 10 | punto fijo
# Processing Record 40 of Set 10 | college
# Processing Record 41 of Set 10 | upington
# Processing Record 42 of Set 10 | namatanai
# Processing Record 43 of Set 10 | igarape-miri
# City not found. Skipping...
# Processing Record 44 of Set 10 | verkhnyaya inta
# Processing Record 45 of Set 10 | khorixas
# Processing Record 46 of Set 10 | gushikawa
# Processing Record 47 of Set 10 | la ronge
# Processing Record 48 of Set 10 | carlagan
# Processing Record 49 of Set 10 | buribay
# Processing Record 50 of Set 10 | iralaya
# Processing Record 1 of Set 11 | nalut
# Processing Record 2 of Set 11 | kyzyl-suu
# Processing Record 3 of Set 11 | bathsheba
# Processing Record 4 of Set 11 | luebo
# Processing Record 5 of Set 11 | kupang
# Processing Record 6 of Set 11 | camacha
# Processing Record 7 of Set 11 | slave lake
# Processing Record 8 of Set 11 | dunedin
# Processing Record 9 of Set 11 | ust-ishim
# Processing Record 10 of Set 11 | waddan
# Processing Record 11 of Set 11 | tambilil
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | miandrivazo
# Processing Record 14 of Set 11 | bischofswerda
# Processing Record 15 of Set 11 | khasan
# Processing Record 16 of Set 11 | gambo
# Processing Record 17 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 11 | katsuura
# Processing Record 19 of Set 11 | sechura
# Processing Record 20 of Set 11 | susanville
# Processing Record 21 of Set 11 | ilhabela
# Processing Record 22 of Set 11 | comodoro rivadavia
# Processing Record 23 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 11 | bambous virieux
# Processing Record 25 of Set 11 | wampusirpi
# City not found. Skipping...
# Processing Record 26 of Set 11 | aksu
# Processing Record 27 of Set 11 | limoges
# Processing Record 28 of Set 11 | newport beach
# Processing Record 29 of Set 11 | kerouane
# Processing Record 30 of Set 11 | balancan
# Processing Record 31 of Set 11 | farah
# Processing Record 32 of Set 11 | iranshahr
# Processing Record 33 of Set 11 | sorland
# Processing Record 34 of Set 11 | plouzane
# Processing Record 35 of Set 11 | havoysund
# Processing Record 36 of Set 11 | beyneu
# Processing Record 37 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 38 of Set 11 | codrington
# Processing Record 39 of Set 11 | augusto correa
# Processing Record 40 of Set 11 | kuusamo
# Processing Record 41 of Set 11 | makakilo city
# Processing Record 42 of Set 11 | sarh
# Processing Record 43 of Set 11 | moose factory
# Processing Record 44 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 11 | khani
# Processing Record 46 of Set 11 | champerico
# Processing Record 47 of Set 11 | san cristobal
# Processing Record 48 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 11 | sinegorskiy
# Processing Record 50 of Set 11 | panguipulli
# Processing Record 1 of Set 12 | solnechnyy
# Processing Record 2 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | tamandare
# Processing Record 4 of Set 12 | kyren
# Processing Record 5 of Set 12 | asau
# Processing Record 6 of Set 12 | albanel
# Processing Record 7 of Set 12 | coihaique
# Processing Record 8 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 9 of Set 12 | lincoln
# Processing Record 10 of Set 12 | merauke
# Processing Record 11 of Set 12 | huarmey
# Processing Record 12 of Set 12 | puerto pailas
# Processing Record 13 of Set 12 | shimoda
# Processing Record 14 of Set 12 | husavik
# Processing Record 15 of Set 12 | richards bay
# Processing Record 16 of Set 12 | fort nelson
# Processing Record 17 of Set 12 | otane
# Processing Record 18 of Set 12 | kaputa
# Processing Record 19 of Set 12 | saint anthony
# Processing Record 20 of Set 12 | port hawkesbury
# Processing Record 21 of Set 12 | sterling
# Processing Record 22 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 12 | strezhevoy
# Processing Record 24 of Set 12 | pinega
# Processing Record 25 of Set 12 | genhe
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | port blair
# Processing Record 28 of Set 12 | belyy yar
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | maragogi
# Processing Record 31 of Set 12 | kulhudhuffushi
# Processing Record 32 of Set 12 | salinopolis
# Processing Record 33 of Set 12 | labuhan
# Processing Record 34 of Set 12 | xingtai
# Processing Record 35 of Set 12 | atikokan
# Processing Record 36 of Set 12 | santa maria
# Processing Record 37 of Set 12 | malappuram
# Processing Record 38 of Set 12 | ust-maya
# Processing Record 39 of Set 12 | zhigalovo
# Processing Record 40 of Set 12 | eydhafushi
# Processing Record 41 of Set 12 | dong hoi
# Processing Record 42 of Set 12 | aswan
# Processing Record 43 of Set 12 | ipoti
# Processing Record 44 of Set 12 | ponta delgada
# Processing Record 45 of Set 12 | tete
# Processing Record 46 of Set 12 | zelenoborskiy
# Processing Record 47 of Set 12 | markova
# Processing Record 48 of Set 12 | zharkent
# Processing Record 49 of Set 12 | vidor
# Processing Record 50 of Set 12 | sarangani
# Processing Record 1 of Set 13 | dreux
# Processing Record 2 of Set 13 | muros
# Processing Record 3 of Set 13 | iquique
# Processing Record 4 of Set 13 | homestead
# Processing Record 5 of Set 13 | livingston
# Processing Record 6 of Set 13 | tikrit
# Processing Record 7 of Set 13 | lazaro cardenas
# Processing Record 8 of Set 13 | pilar
# Processing Record 9 of Set 13 | archidona
# Processing Record 10 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 11 of Set 13 | charters towers
# Processing Record 12 of Set 13 | artyom
# Processing Record 13 of Set 13 | epe
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | te anau
# Processing Record 16 of Set 13 | alhama de murcia
# Processing Record 17 of Set 13 | shuyskoye
# Processing Record 18 of Set 13 | kazerun
# Processing Record 19 of Set 13 | tukrah
# Processing Record 20 of Set 13 | portobelo
# Processing Record 21 of Set 13 | acarau
# Processing Record 22 of Set 13 | parras
# City not found. Skipping...
# Processing Record 23 of Set 13 | vanimo
# Processing Record 24 of Set 13 | williston
# Processing Record 25 of Set 13 | abu samrah
# Processing Record 26 of Set 13 | lyubim
# Processing Record 27 of Set 13 | manado
# Processing Record 28 of Set 13 | soe
# Processing Record 29 of Set 13 | bosaso
# Processing Record 30 of Set 13 | panama city
# Processing Record 31 of Set 13 | buala
# Processing Record 32 of Set 13 | troitskoye
# Processing Record 33 of Set 13 | bandarbeyla
# Processing Record 34 of Set 13 | shieli
# Processing Record 35 of Set 13 | phan thiet
# Processing Record 36 of Set 13 | penarroya-pueblonuevo
# Processing Record 37 of Set 13 | moba
# Processing Record 38 of Set 13 | flin flon
# Processing Record 39 of Set 13 | horodkivka
# Processing Record 40 of Set 13 | dindori
# Processing Record 41 of Set 13 | lavrentiya
# Processing Record 42 of Set 13 | ewa beach
# Processing Record 43 of Set 13 | ratnagiri
# Processing Record 44 of Set 13 | jinji
# Processing Record 45 of Set 13 | huntsville
# Processing Record 46 of Set 13 | bijie
# Processing Record 47 of Set 13 | grants
# Processing Record 48 of Set 13 | nola
# Processing Record 49 of Set 13 | islamkot
# Processing Record 50 of Set 13 | yilan
# Processing Record 1 of Set 14 | kantang
# Processing Record 2 of Set 14 | gunjur
# Processing Record 3 of Set 14 | wladyslawowo
# Processing Record 4 of Set 14 | grafton
# Processing Record 5 of Set 14 | saint-pierre
# Processing Record 6 of Set 14 | samarai
# Processing Record 7 of Set 14 | llandrindod wells
# Processing Record 8 of Set 14 | pahrump
# Processing Record 9 of Set 14 | geghamasar
# Processing Record 10 of Set 14 | paamiut
# Processing Record 11 of Set 14 | boundiali
# Processing Record 12 of Set 14 | itoman
# Processing Record 13 of Set 14 | celestun
# Processing Record 14 of Set 14 | turka
# Processing Record 15 of Set 14 | viransehir
# Processing Record 16 of Set 14 | paita
# Processing Record 17 of Set 14 | pogar
# Processing Record 18 of Set 14 | sao felix do xingu
# Processing Record 19 of Set 14 | hirado
# Processing Record 20 of Set 14 | fairbanks
# Processing Record 21 of Set 14 | noyabrsk
# Processing Record 22 of Set 14 | ninghai
# Processing Record 23 of Set 14 | atasu
# Processing Record 24 of Set 14 | gao
# Processing Record 25 of Set 14 | port hedland
# Processing Record 26 of Set 14 | kutum
# Processing Record 27 of Set 14 | nsoko
# Processing Record 28 of Set 14 | omboue
# Processing Record 29 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 30 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 14 | conceicao do araguaia
# Processing Record 32 of Set 14 | nueva helvecia
# Processing Record 33 of Set 14 | ucluelet
# Processing Record 34 of Set 14 | aguimes
# Processing Record 35 of Set 14 | abnub
# Processing Record 36 of Set 14 | santa cruz
# Processing Record 37 of Set 14 | ahipara
# Processing Record 38 of Set 14 | monrovia
# Processing Record 39 of Set 14 | viedma
# Processing Record 40 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 14 | alugan
# Processing Record 42 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 43 of Set 14 | vidim
# Processing Record 44 of Set 14 | llata
# Processing Record 45 of Set 14 | rocha
# Processing Record 46 of Set 14 | marsa matruh
# Processing Record 47 of Set 14 | jalu
# Processing Record 48 of Set 14 | fuerte olimpo
# Processing Record 49 of Set 14 | barabai
# Processing Record 50 of Set 14 | nouakchott
# Processing Record 1 of Set 15 | teya
# Processing Record 2 of Set 15 | brokopondo
# Processing Record 3 of Set 15 | hokitika
# Processing Record 4 of Set 15 | yeppoon
# Processing Record 5 of Set 15 | auki
# Processing Record 6 of Set 15 | san joaquin
# Processing Record 7 of Set 15 | el wasta
# City not found. Skipping...
# Processing Record 8 of Set 15 | nombre de jesus
# Processing Record 9 of Set 15 | gangarampur
# Processing Record 10 of Set 15 | salamiyah
# Processing Record 11 of Set 15 | xanlar
# Processing Record 12 of Set 15 | biltine
# Processing Record 13 of Set 15 | pacific grove
# Processing Record 14 of Set 15 | nagamangala
# Processing Record 15 of Set 15 | stornoway
# Processing Record 16 of Set 15 | guangyuan
# Processing Record 17 of Set 15 | log
# Processing Record 18 of Set 15 | tokur
# Processing Record 19 of Set 15 | bisira
# Processing Record 20 of Set 15 | tucupita
# Processing Record 21 of Set 15 | sovetskiy
# Processing Record 22 of Set 15 | buinsk
# Processing Record 23 of Set 15 | tignere
# Processing Record 24 of Set 15 | pandan
# Processing Record 25 of Set 15 | siniscola
# Processing Record 26 of Set 15 | kahului
# Processing Record 27 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 15 | lubango
# Processing Record 29 of Set 15 | porto novo
# Processing Record 30 of Set 15 | nipawin
# Processing Record 31 of Set 15 | kapuskasing
# Processing Record 32 of Set 15 | puro
# Processing Record 33 of Set 15 | cururupu
# Processing Record 34 of Set 15 | qaqortoq
# Processing Record 35 of Set 15 | natal
# Processing Record 36 of Set 15 | victoria point
# Processing Record 37 of Set 15 | necochea
# Processing Record 38 of Set 15 | cayenne
# Processing Record 39 of Set 15 | salta
# Processing Record 40 of Set 15 | podor
# Processing Record 41 of Set 15 | hingatungan
# Processing Record 42 of Set 15 | dandong
# Processing Record 43 of Set 15 | tual
# Processing Record 44 of Set 15 | whitianga
# Processing Record 45 of Set 15 | wanning
# Processing Record 46 of Set 15 | mokrousovo
# Processing Record 47 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 15 | les cayes
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 683

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini      TO -21.2000 -175.2000     82.56        83          40
# 1          Atuona      PF  -9.8000 -139.0333     78.39        71         100
# 2        Tay Ninh      VN  11.3000  106.1000     77.40        87         100
# 3         Mataura      NZ -46.1927  168.8643     57.25        59          65
# 4      Butaritari      KI   3.0707  172.7902     81.70        72          31
# 5  Port Elizabeth      ZA -33.9180   25.5701     51.10        65          98
# 6     Tuktoyaktuk      CA  69.4541 -133.0374     27.05        79          60
# 7       Cape Town      ZA -33.9258   18.4232     53.28        66           0
# 8          Marawi      PH   7.9986  124.2928     74.64        70          91
# 9         Dolores      AR -36.3132  -57.6792     49.91        94          77
#
#    Wind Speed Current Description
# 0       10.36    scattered clouds
# 1       18.48     overcast clouds
# 2        3.02     overcast clouds
# 3        6.67       broken clouds
# 4       12.26    scattered clouds
# 5        7.72     overcast clouds
# 6        9.31       broken clouds
# 7       10.20           clear sky
# 8        0.92     overcast clouds
# 9       10.27       broken clouds

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City ID")
